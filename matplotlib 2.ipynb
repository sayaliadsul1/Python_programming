# %%
# 19/4/22

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y)
plt.grid()
plt.show()

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y)
plt.grid(color="r")
plt.show()

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y)
plt.grid(color="r",axis="x")
plt.show()

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y)
plt.grid(color="r",axis="y")
plt.show()

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y)
plt.grid(color="r",ls="--",linewidth="2")
plt.show()

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y,"o")
plt.grid(color="r",ls="--",linewidth="2")
plt.show()

# %%
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])

plt.plot(x,y)
plt.grid(color="r",ls="--",linewidth="2")
plt.title("Data Science")
plt.xlabel("This is X axis")
plt.ylabel("This is Y axis")
plt.show()

# %%
# plot 1
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(1,2,1)
plt.plot(x,y,marker="o",mec="y",color="black")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Data Science")






# plot 2
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(1,2,2)
plt.plot(x,y,mfc="b",marker="p",mec="y",color="hotpink")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Data Science")







plt.show()

# %%
# plot 1
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,1)
plt.plot(x,y,marker="o",mec="y",color="black")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Python")






# plot 2
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,2)
plt.plot(x,y,mfc="b",marker="p",mec="y",color="hotpink")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Data Science")


# plot 3
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,3)
plt.plot(x,y,marker="o",mec="y",color="black")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Machine Learning")






# plot 4
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,4)
plt.plot(x,y,mfc="b",marker="p",mec="y",color="hotpink")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("AI")




plt.show()

# %%
# plot 1
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,1)
plt.plot(x,y,marker="o",mec="y",color="black")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Python")






# plot 2
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,2)
plt.plot(x,y,mfc="b",marker="p",mec="y",color="hotpink")
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Data Science")


# plot 3
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,3)
plt.bar(x,y)
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("Machine Learning")






# plot 4
x=np.array([2,3,4,5,7])
y=np.array([10,25,40,150,250])
plt.subplot(2,2,4)
plt.scatter(x,y)
plt.grid(color="grey",ls="--",linewidth="2")
plt.title("AI")




plt.show()
