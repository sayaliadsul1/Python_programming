# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv(r"C:\Users\Acer\Desktop\Dataset\winequality.csv")

# %%
data1
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data1.shape
# Out:
# (6497, 13)

# %%
data1.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
data=data1.dropna()

# %%
data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data["alcohol"].max()
# Out:
# 14.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6463 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6463 non-null   object
#  1   fixed acidity         6463 non-null   float64
#  2   volatile acidity      6463 non-null   float64
#  3   citric acid           6463 non-null   float64
#  4   residual sugar        6463 non-null   float64
#  5   chlorides             6463 non-null   float64
#  6   free sulfur dioxide   6463 non-null   float64
#  7   total sulfur dioxide  6463 non-null   float64
#  8   density               6463 non-null   float64
#  9   pH                    6463 non-null   float64
#  10  sulphates             6463 non-null   float64
#  11  alcohol               6463 non-null   float64
#  12  quality               6463 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 706.9+ KB

# %%
data["type"].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
data["type"]=data["type"].map({"white":0,"red":1})
# Out:
# C:\Users\Acer\AppData\Local\Temp/ipykernel_8828/4050279535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["type"]=data["type"].map({"white":0,"red":1})

# %%
data
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # 1) Find the value count of white and red wine and show in a graphical?

# %%
data["type"].value_counts()
# Out:
# 0    4870
# 1    1593
# Name: type, dtype: int64

# %%
x=np.array(["white","red"])
y=np.array([4870,1593])
plt.bar(x,y)
plt.xlabel("Type Of Wine")
plt.ylabel("count")
plt.show()

# %%
data["quality"].value_counts()
# Out:
# 6    2820
# 5    2128
# 7    1074
# 4     214
# 8     192
# 3      30
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# # 2) What is the proportion of each type of based on quality scaled 0-10?

# %%
d1=data.loc[(data["quality"]>=0) & (data["quality"]<=4)]
d1
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 46       0            6.2             0.450         0.26             4.4
# 115      0            5.5             0.485         0.00             1.5
# 147      0            6.4             0.595         0.14             5.2
# 172      0            7.6             0.480         0.37             0.8
# 176      0            7.2             0.320         0.47             5.1
# ...    ...            ...               ...          ...             ...
# 6378     1            5.6             0.620         0.03             1.5
# 6380     1            7.2             0.580         0.54             2.1
# 6382     1            6.8             0.910         0.06             2.0
# 6403     1            6.7             0.760         0.02             1.8
# 6419     1            6.9             0.480         0.20             1.9
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
d1["quality"].count()
# Out:
# 244

# %%
d2=data.loc[(data["quality"]>=5) & (data["quality"]<=7)]
d2
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
d2["quality"].count()
# Out:
# 6022

# %%
d3=data.loc[(data["quality"]>=8) & (data["quality"]<=10)]
d3
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 20       0            6.2              0.66         0.48             1.2
# 22       0            6.8              0.26         0.42             1.7
# 68       0            6.7              0.23         0.31             2.1
# 74       0            6.7              0.23         0.31             2.1
# 158      0            5.2              0.44         0.04             1.4
# ...    ...            ...               ...          ...             ...
# 6100     1            8.6              0.42         0.39             1.8
# 6167     1            5.5              0.49         0.03             1.8
# 6301     1            7.2              0.33         0.33             1.7
# 6347     1            7.2              0.38         0.31             2.0
# 6447     1            7.4              0.36         0.30             1.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
d3["quality"].count()
# Out:
# 197

# %%
x3=np.array(["Poor Quality","Normal quality","Good quality"])
y3=np.array([244,6022,197])

# %%
plt.pie(y3,labels=x3,radius=1.5,autopct="%0.1f%%")
plt.show()

# %% [markdown]
# # 3) Find the count of how many types of wine quality are Normal,Poor and Good?

# %%
x3=np.array(["Poor Quality","Normal quality","Good quality"])
y3=np.array([244,6022,197])
plt.bar(x3,y3)
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 4) Find the value count of high number in quality ?

# %%
x4=np.array([3,4,5,6,7,8,9])
y4=np.array([30,214,2128,2820,1074,192,5])
plt.bar(x4,y4)
plt.xlabel("Quality category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 5) What is the proportion of alcohol in white and red wine ?

# %%
data
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...
