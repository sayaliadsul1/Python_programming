# %%
# 18/4/22

# %%
import matplotlib.pyplot as plt

# %%
import pandas as ps
import numpy as np

# %%
x=np.array([2,5,8,10])
y=np.array([20,40,90,180])
plt.plot(x,y)
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y)
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,"o")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,"*")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,"s")                     # s=square
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,"p")                   # p=polygon
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,"x")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,"X")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])

x1=np.array([2,6,9,12,20,22])
y1=np.array([25,45,95,185,50,35])

plt.plot(x,y,"o")
plt.plot(x1,y1,"*")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])

x1=np.array([2,6,9,12,20,22])
y1=np.array([25,45,95,185,50,35])

plt.plot(x,y)
plt.plot(x1,y1)
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
#plt.plot(x,y,color="b")      
#plt.plot(x,y,color="black")
#plt.plot(x,y,color="y")
#plt.plot(x,y,color="r")
#plt.plot(x,y,color="g")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,ms="10",marker="*",mfc="black",mec="red")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="-")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
#plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="--")
#plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="-.")
#plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="None")
#plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="solid")
#plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="dashed")
#plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="dotted")
plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="dashdot")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="-.",linewidth="5")
plt.show()

# %%
x=np.array([2,5,8,10,17,20])
y=np.array([20,40,90,180,45,30])
plt.plot(x,y,color="red",ms="10",marker="*",mfc="red",mec="b",linestyle="-.",linewidth="5")
plt.grid()
plt.show()
